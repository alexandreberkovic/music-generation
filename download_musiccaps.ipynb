# %% [markdown]
# # Downloading Clips from the MusicCaps Dataset
#
# In this notebook, we see how you can use `yt-dlp` to download clips from the [MusicCaps](https://huggingface.co/datasets/google/MusicCaps) dataset from Google. The MusicCaps dataset contains music and their associated text captions. You could use a dataset like this to train a text-to-audio generation model 😉.
#
# Once we've downloaded the clips, we'll explore them using a [Gradio](https://gradio.app/) interface.
#
# If you like this notebook:
#
#   - consider giving the [repo](https://github.com/nateraw/download-musiccaps-dataset) a star ⭐️
#   - consider following me on Github [@nateraw](https://github.com/nateraw)

# %%
# %%capture
! pip install datasets[audio] yt-dlp

# For the interactive interface we'll need gradio
! pip install gradio

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import subprocess
import os
from pathlib import Path
import librosa
import numpy as np
from PIL import Image

from datasets import load_dataset
import shutil


def download_clip(
    video_identifier,
    output_filename,
    start_time,
    end_time,
    tmp_dir='/tmp/musiccaps',
    num_attempts=5,
    url_base='https://www.youtube.com/watch?v='
):
    status = False

    command = f"""
        yt-dlp --quiet --no-warnings -x --audio-format wav -f bestaudio -o "{output_filename}" --download-sections "*{start_time}-{end_time}" {url_base}{video_identifier}
    """.strip()

    attempts = 0
    while True:
        try:
            output = subprocess.check_output(command, shell=True,
                                                stderr=subprocess.STDOUT)
        except subprocess.CalledProcessError as err:
            attempts += 1
            if attempts == num_attempts:
                return status, err.output
        else:
            break

    # Check if the video was successfully saved.
    status = os.path.exists(output_filename)
    return status, 'Downloaded'


def main(
    spectrogram_dir: str,
    limit: int = None,
    num_proc: int = 1,
    writer_batch_size: int = 1000,
    keep_in_memory: bool = False
):
    """
    Download the clips within the MusicCaps dataset from YouTube and store their spectrograms.
    Args:
        spectrogram_dir: Directory to save the spectrograms to.
        limit: Limit the number of examples to download.
    """

    ds = load_dataset('google/MusicCaps', split='train')
    if limit is not None:
        print(f"Limiting to {limit} examples")
        ds = ds.select(range(limit))

    spectrogram_dir = Path(spectrogram_dir)
    spectrogram_dir.mkdir(exist_ok=True, parents=True)

    def process(example):
      try:
          spectrogram_file = spectrogram_dir / f"{example['ytid']}.png"
          if not spectrogram_file.exists():
              audio_file = f"/tmp/musiccaps/{example['ytid']}.wav"
              try:
                  if not os.path.exists(audio_file):
                      download_clip(
                          example['ytid'],
                          audio_file,
                          example['start_s'],
                          example['end_s'],
                      )
                  y, sr = librosa.load(audio_file, sr=None, mono=True)
                  S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=1024, n_mels=128)
                  S_dB = librosa.power_to_db(S, ref=np.max)
                  plt.figure(figsize=(10, 5))
                  librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, fmax=8000)
                  plt.axis('off')
                  plt.savefig(spectrogram_file, bbox_inches='tight', pad_inches=0, dpi=100)
                  plt.close()
              except:
                  print(f"Failed to process {audio_file}")
                  return None
          example['spectrogram'] = str(spectrogram_file)
          return example
      except:
          print(f"Failed to process example with ID {example['ytid']}")
          return None


    ds = ds.map(
        process,
        num_proc=num_proc,
        keep_in_memory=keep_in_memory,
        writer_batch_size = writer_batch_size
    )

    # Remove examples that failed to process
    ds = ds.filter(lambda x: x is not None)

    # Zip and download the data directory
    shutil.make_archive('spectrogram_all_images', 'zip', spectrogram_dir)
    files.download('spectrogram_all_images.zip')

    return ds

# %% [markdown]
# ## Load the Dataset
#
# Here we are limiting to the first 32 examples. Since Colab is constrained to 2 cores, downloading the whole dataset here would take hours.
#
# When running this on your own machine:
#   - you can set `limit=None` to download + process the full dataset. Feel free to do that here in Colab, it'll just take a long time.
#   - you should increase the `num_proc`, which will speed things up substantially
#   - If you run out of memory, try reducing the `writer_batch_size`, as by default, it will keep 1000 examples in memory *per worker*.

# %%
ds = main('./spectrogram_data_everything_5', num_proc=1, writer_batch_size=100, keep_in_memory=False)
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/google___csv/google--MusicCaps-bedc2a0fd7888f2f/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
# Map:   0%|          | 0/5521 [00:00<?, ? examples/s]
# Failed to process /tmp/musiccaps/-0Gj8-vB1q4.wav
# Failed to process /tmp/musiccaps/-0SdAVK79lg.wav
# Failed to process /tmp/musiccaps/-0vPFx-wRRI.wav
# Failed to process /tmp/musiccaps/-0xzrMun0Rs.wav
# Failed to process /tmp/musiccaps/-1LrH01Ei1w.wav
# Failed to process /tmp/musiccaps/-1OlgJWehn8.wav
# Failed to process /tmp/musiccaps/-1UWSisR2zo.wav
# Failed to process /tmp/musiccaps/-3Kv4fdm7Uk.wav
# Failed to process /tmp/musiccaps/-4NLarMj4xU.wav
# Failed to process /tmp/musiccaps/-4SYC2YgzL8.wav
# Failed to process /tmp/musiccaps/-5FoeegAgvU.wav
# Failed to process /tmp/musiccaps/-5f6hjZf9Yw.wav
# Failed to process /tmp/musiccaps/-5xOcMJpTUk.wav
# Failed to process /tmp/musiccaps/-6HBGg1cAI0.wav
# Failed to process /tmp/musiccaps/-6QGvxvaTkI.wav
# Failed to process /tmp/musiccaps/-6pcgdLfb_A.wav
# Failed to process /tmp/musiccaps/-7B9tPuIP-w.wav
# Failed to process /tmp/musiccaps/-7wUQP6G5EQ.wav
# Failed to process /tmp/musiccaps/-88me9bBzrk.wav
# Failed to process /tmp/musiccaps/-8C-gydUbR8.wav
# Failed to process /tmp/musiccaps/-8cgbhIR_pw.wav
# Failed to process /tmp/musiccaps/-BHPu-dPmWQ.wav
# Failed to process /tmp/musiccaps/-BIMKnb3tlo.wav
# Failed to process /tmp/musiccaps/-Bu7YaslRW0.wav
# Failed to process /tmp/musiccaps/-ByoSbgzr4M.wav
# Failed to process /tmp/musiccaps/-CUp_Tmg2Y0.wav
# Failed to process /tmp/musiccaps/-DeAdhYKbGE.wav
# Failed to process /tmp/musiccaps/-Dtir74TiUM.wav
# Failed to process /tmp/musiccaps/-EVRXQpt1-8.wav
# Failed to process /tmp/musiccaps/-FEPOSP7ay0.wav
# Failed to process /tmp/musiccaps/-FFx68qSAuY.wav
# Failed to process /tmp/musiccaps/-FlvaZQOr2I.wav
# Failed to process /tmp/musiccaps/-Gf4Ihv1zwc.wav
# Failed to process /tmp/musiccaps/-IZbvEO9wzU.wav
# Failed to process /tmp/musiccaps/-JVWfFPBl84.wav
# Failed to process /tmp/musiccaps/-JvB5AL59fM.wav
# Failed to process /tmp/musiccaps/-M-6VinyMiY.wav
# Failed to process /tmp/musiccaps/-M6K3QoHh40.wav
# Failed to process /tmp/musiccaps/-NmjCyqIavI.wav
# Failed to process /tmp/musiccaps/-O9mnfC61Ac.wav
# Failed to process /tmp/musiccaps/-OAyRsvFGgc.wav
# Failed to process /tmp/musiccaps/-OUIEnuNd1I.wav
# Failed to process /tmp/musiccaps/-Q9MTRXS4bE.wav
# Failed to process /tmp/musiccaps/-QuWdnmn-kM.wav
# Failed to process /tmp/musiccaps/-R0267o4lLk.wav
# Failed to process /tmp/musiccaps/-RYtUAsNhF0.wav
# Failed to process /tmp/musiccaps/-SD43H5B5hE.wav
# Failed to process /tmp/musiccaps/-SWaCArvQug.wav
# Failed to process /tmp/musiccaps/-T4GeTHKtJQ.wav
# Failed to process /tmp/musiccaps/-U16iKiXGuY.wav
# Failed to process /tmp/musiccaps/-Umconw-CRE.wav
# Failed to process /tmp/musiccaps/-UuEBhule84.wav
# Failed to process /tmp/musiccaps/-VI2IRq17rs.wav
# Failed to process /tmp/musiccaps/-VclCul6FrI.wav
# Failed to process /tmp/musiccaps/-Vo4CAMX26U.wav
# Failed to process /tmp/musiccaps/-W5c6CeUMPE.wav
# Failed to process /tmp/musiccaps/-WvVG0wHcTc.wav
# Failed to process /tmp/musiccaps/-XN0NtrnfMY.wav
# Failed to process /tmp/musiccaps/-XkbErI_7EU.wav
# Failed to process /tmp/musiccaps/-YATTKBtmRA.wav
# Failed to process /tmp/musiccaps/-YIT4HBM__g.wav
# Failed to process /tmp/musiccaps/-ZHpNr_KRXU.wav
# Failed to process /tmp/musiccaps/-_6RxZyi30Q.wav
# Failed to process /tmp/musiccaps/-_OzT7Xyvok.wav
# Failed to process /tmp/musiccaps/-bgHkxwoliw.wav
# Failed to process /tmp/musiccaps/-cLzki-B06o.wav
# Failed to process /tmp/musiccaps/-cQ-jUTEgck.wav
# Failed to process /tmp/musiccaps/-dVgUSrR8g4.wav
# Failed to process /tmp/musiccaps/-e4wXAy1iVo.wav
# Failed to process /tmp/musiccaps/-eDAoheZrY8.wav
# Failed to process /tmp/musiccaps/-f1DNyngKVY.wav
# Failed to process /tmp/musiccaps/-f6s6kQEHFY.wav
# Failed to process /tmp/musiccaps/-fxh7jAJR8U.wav
# Failed to process /tmp/musiccaps/-hSMzrWZCAE.wav
# Failed to process /tmp/musiccaps/-hYRFCQdbLg.wav
# Failed to process /tmp/musiccaps/-i9gpG3vPwA.wav
# Failed to process /tmp/musiccaps/-i9uQMysy_A.wav
# Failed to process /tmp/musiccaps/-jpbCWcz2pk.wav
# Failed to process /tmp/musiccaps/-kpR93atgd8.wav
# Failed to process /tmp/musiccaps/-lPXTBXa0tE.wav
# Failed to process /tmp/musiccaps/-m5ZlWziIeA.wav
# Failed to process /tmp/musiccaps/-m9pH0WXQto.wav
# Failed to process /tmp/musiccaps/-mA_bqD1tgU.wav
# Failed to process /tmp/musiccaps/-mB_XLq6g1g.wav
# Failed to process /tmp/musiccaps/-nlkWWphiaM.wav
# Failed to process /tmp/musiccaps/-o0ZtQIkM60.wav
# Failed to process /tmp/musiccaps/-oP-XX28B0s.wav
# Failed to process /tmp/musiccaps/-pUfYFcsgG4.wav
# Failed to process /tmp/musiccaps/-qcTD2o6I9s.wav
# Failed to process /tmp/musiccaps/-r2-9oyIzkQ.wav
# Failed to process /tmp/musiccaps/-r7iz-9v9bA.wav
# Failed to process /tmp/musiccaps/-rAhS48FkYw.wav
# Failed to process /tmp/musiccaps/-sRFfU8k0Zs.wav
# Failed to process /tmp/musiccaps/-sevczF5etI.wav
# Failed to process /tmp/musiccaps/-tKZOl4q1Kw.wav
# Failed to process /tmp/musiccaps/-taO6N-rxv4.wav
# Failed to process /tmp/musiccaps/-tmY1GEH3_Y.wav
# Failed to process /tmp/musiccaps/-tpq_bzSKes.wav
# Failed to process /tmp/musiccaps/-uaTK8sa5Ms.wav
# Failed to process /tmp/musiccaps/-v5hgCh3M2w.wav
# Failed to process /tmp/musiccaps/-w12aSkQ9No.wav
# Failed to process /tmp/musiccaps/-w4HLksto_k.wav
# Failed to process /tmp/musiccaps/-w8maIWtnUk.wav
# Failed to process /tmp/musiccaps/-wVWjl9Kq6U.wav
# Failed to process /tmp/musiccaps/-wymN80CiYU.wav
# Failed to process /tmp/musiccaps/-zA6LL78KYU.wav
# Failed to process /tmp/musiccaps/-zOybsEdM5E.wav
# Failed to process /tmp/musiccaps/0-7PyzhzuYQ.wav
# Failed to process /tmp/musiccaps/00M9FhCet6s.wav
# Failed to process /tmp/musiccaps/01PzcPKT3_E.wav
# Failed to process /tmp/musiccaps/01hjVJN9xCg.wav
# Failed to process /tmp/musiccaps/0298WjE3_tk.wav
# Failed to process /tmp/musiccaps/02Qntw26enM.wav
# Failed to process /tmp/musiccaps/03frQGyrgQ4.wav
# Failed to process /tmp/musiccaps/03z0rpIkm5g.wav
# Failed to process /tmp/musiccaps/04NjXsLyCl4.wav
# Failed to process /tmp/musiccaps/05JAmKFVy44.wav
# Failed to process /tmp/musiccaps/05OJDYeHLMc.wav
# Failed to process /tmp/musiccaps/06Brdf83RZE.wav
# Failed to process /tmp/musiccaps/06IU9WsEp3s.wav
# Failed to process /tmp/musiccaps/07-3grCQ8EU.wav
# Failed to process /tmp/musiccaps/07-vpXo91XM.wav
# Failed to process /tmp/musiccaps/07FxCXxknY4.wav
# Failed to process /tmp/musiccaps/07mS0mSTDjY.wav
# Failed to process /tmp/musiccaps/07xGXxIHOL4.wav
# Failed to process /tmp/musiccaps/08mf5GxT820.wav
# Failed to process /tmp/musiccaps/08u-jdwjM74.wav
# Failed to process /tmp/musiccaps/09lQmg2wvsY.wav
# Failed to process /tmp/musiccaps/0ADP-O_V3vA.wav
# Failed to process /tmp/musiccaps/0AGHo8V8HpM.wav
# Failed to process /tmp/musiccaps/0AhX-ReXovI.wav
# Failed to process /tmp/musiccaps/0BFauf6TGGU.wav
# Failed to process /tmp/musiccaps/0DYH0sqDXB8.wav
# Failed to process /tmp/musiccaps/3XL825fK6UM.wav
# Failed to process /tmp/musiccaps/3XRjrSOVBnQ.wav
# Failed to process /tmp/musiccaps/3XeMR8lX0dg.wav
# Failed to process /tmp/musiccaps/3Xoz87_SUdw.wav
# Failed to process /tmp/musiccaps/3Yc7_n6mDsI.wav
# Failed to process /tmp/musiccaps/3YuO2UOYKRk.wav
# Failed to process /tmp/musiccaps/3Z74i_FWs3o.wav
# Failed to process /tmp/musiccaps/3ZhyXbwFQAM.wav
# Failed to process /tmp/musiccaps/3ZyuBJEbmJM.wav
# Failed to process /tmp/musiccaps/3_M9ZMo5TiU.wav
# Failed to process /tmp/musiccaps/3b3s0TvjGwA.wav
# Failed to process /tmp/musiccaps/3bg0iy-ypcw.wav
# Failed to process /tmp/musiccaps/3cEQfNZ_F1w.wav
# Failed to process /tmp/musiccaps/3dUo62RsD00.wav
# Failed to process /tmp/musiccaps/3dzR3ZWOe8Y.wav
# Failed to process /tmp/musiccaps/3e6GleQ9sl0.wav
# Failed to process /tmp/musiccaps/3fqWosszpnE.wav
# Failed to process /tmp/musiccaps/3gh1oldZ7Zc.wav
# Failed to process /tmp/musiccaps/3jLef5eHgzU.wav
# Failed to process /tmp/musiccaps/3kSQNjfJnN8.wav
# Failed to process /tmp/musiccaps/3kXukXBvDQQ.wav
# Failed to process /tmp/musiccaps/3m-a805cVl0.wav
# Failed to process /tmp/musiccaps/3m4QSVVBMss.wav
# Failed to process /tmp/musiccaps/3mNOJpN_qOQ.wav
# Failed to process /tmp/musiccaps/3mStyfCbL68.wav
# Failed to process /tmp/musiccaps/3nbB3F-OdSM.wav
# Failed to process /tmp/musiccaps/3nfiGGQykxk.wav
# Failed to process /tmp/musiccaps/3noh9LiQNrs.wav
# Failed to process /tmp/musiccaps/3obJKn19jTE.wav
# Failed to process /tmp/musiccaps/3otUlQ4wvLY.wav
# Failed to process /tmp/musiccaps/3pU34vUoO9g.wav
# Failed to process /tmp/musiccaps/3q9K2PgA2-U.wav
# Failed to process /tmp/musiccaps/3rbWoeUg9yo.wav
# Failed to process /tmp/musiccaps/3rvqiSZB4pA.wav
# Failed to process /tmp/musiccaps/3sIlpn9nvKU.wav
# Failed to process /tmp/musiccaps/3sRO6iwfUxo.wav
# Failed to process /tmp/musiccaps/3tK7PpCo0PQ.wav
# Failed to process /tmp/musiccaps/3tSPMzvuQpk.wav
# Failed to process /tmp/musiccaps/3tbFP_JKzXw.wav
# Failed to process /tmp/musiccaps/3tlaELkmRqs.wav
# Failed to process /tmp/musiccaps/3tyb0cXoX2g.wav
# Failed to process /tmp/musiccaps/3u9OO9Og0Gc.wav
# Failed to process /tmp/musiccaps/3ujGrObyefA.wav
# Failed to process /tmp/musiccaps/3uz_ZrGsIaA.wav
# Failed to process /tmp/musiccaps/3vEsFxolnFs.wav
# Failed to process /tmp/musiccaps/3w3fD54bNvU.wav
# Failed to process /tmp/musiccaps/3w4nFQrUQ8k.wav
# Failed to process /tmp/musiccaps/3w_LsKl-3Pk.wav
# Failed to process /tmp/musiccaps/3zIQTDfS4Hk.wav
# Failed to process /tmp/musiccaps/4T_5clu_0OM.wav
# Failed to process /tmp/musiccaps/4Ua6i_VDYU4.wav
# Failed to process /tmp/musiccaps/4Udqs0trpMw.wav
# Failed to process /tmp/musiccaps/4VbXYuCz4M0.wav
# Failed to process /tmp/musiccaps/4Vg0PQuHTk0.wav
# Failed to process /tmp/musiccaps/4W3Ql8JbEN8.wav
# Failed to process /tmp/musiccaps/4W8BYc8ZMaE.wav
# Failed to process /tmp/musiccaps/4W8IZxn3nEI.wav
# Failed to process /tmp/musiccaps/4X2aUZFZlzc.wav
# Failed to process /tmp/musiccaps/4Y5VcH7iK3Q.wav
# Failed to process /tmp/musiccaps/4Yc71_dU3m4.wav
# Failed to process /tmp/musiccaps/4ZwGxgOwBUc.wav
# Failed to process /tmp/musiccaps/4_s5vHgfxnw.wav
# Failed to process /tmp/musiccaps/4a1a-lmDVaY.wav
# Failed to process /tmp/musiccaps/4b8gTARnmVE.wav
# Failed to process /tmp/musiccaps/4bXb6GLm6zg.wav
# Failed to process /tmp/musiccaps/4cg3MsrvJqw.wav
# Failed to process /tmp/musiccaps/4dilYyxYLmM.wav
# Failed to process /tmp/musiccaps/4ezo771lGts.wav
# Failed to process /tmp/musiccaps/4gEmWJCPZGo.wav
# Failed to process /tmp/musiccaps/4hulNRgH6cI.wav
# Failed to process /tmp/musiccaps/4i11P4OCRfk.wav
# Failed to process /tmp/musiccaps/4i1aizhCnfg.wav
# Failed to process /tmp/musiccaps/4i9DgH80kDg.wav
# Failed to process /tmp/musiccaps/4jzr88nEdCM.wav
# Failed to process /tmp/musiccaps/4kKVGPDCIK8.wav
# Failed to process /tmp/musiccaps/4kZ0EZg5JRU.wav
# Failed to process /tmp/musiccaps/4kyWH8eWP8M.wav
# Failed to process /tmp/musiccaps/4l441DdEJfU.wav
# Failed to process /tmp/musiccaps/4lcZkOMhKv8.wav

# %% [markdown]
# Let's explore the samples using a quick Gradio Interface 🤗

# %%
import gradio as gr

def get_example(idx):
    ex = ds[idx]
    return ex['audio']['path'], ex['caption']

gr.Interface(
    get_example,
    inputs=gr.Slider(0, len(ds) - 1, value=0, step=1),
    outputs=['audio', 'textarea'],
    live=True
).launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
# extract the spectrograms from the audio files
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

def get_spectrogram(audio_path):
    y, sr = librosa.load(audio_path, sr=44100)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
    return librosa.power_to_db(S, ref=np.max)

def plot_spectrogram(audio_path):
    S = get_spectrogram(audio_path)
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S, y_axis='mel', fmax=8000, x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    plt.tight_layout()
    plt.show()

plot_spectrogram(ds[0]['audio']['path'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-92d40bc51bb2> in <cell line: 21>()
#      19     plt.show()
#      20
# ---> 21 plot_spectrogram(ds[0]['audio']['path'])
#
# KeyError: 'audio'
